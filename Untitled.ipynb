# %%
from __future__ import division 
import os, sys
import numpy as np
import pandas as pd 
from sklearn.utils import shuffle as reset
# %matplotlib inline
import matplotlib.pyplot as plt
import random

# %%
def loadDataSet(fileName):
    return pd.read_csv(fileName, header=None, encoding='utf-8', sep = '\t')

# %%
def train_test_split(data, test_size=0.3, shuffle=True, random_state=None):
    if shuffle:
        data = reset(data, random_state=random_state)
    train = data[int(len(data)*test_size):].reset_index(drop = True)
    test  = data[:int(len(data)*test_size)].reset_index(drop = True)
    return train, test

# %%
def standRegres(xArr,yArr):    
    xMat = np.mat(xArr); yMat = np.mat(yArr).T  # list转换成mat    
    xTx = xMat.T * xMat    
    if np.linalg.det(xTx) == 0.0:  # 矩阵的逆可能并不存在，要在代码中对此作出判断        
        print("This matrix is singular, cannot do inverse")        
        return    
    ws = xTx.I * (xMat.T * yMat)    
    return ws

# %%
def absError(yArr,yHatArr):
    return abs(yArr-yHatArr).sum()/len(yArr)

def distance(lon,lat):
    return 110*sqrt(lon**2 + lat**2)

# %%
rawdata = loadDataSet('./data/typhoon.dat').as_matrix()
random.shuffle(rawdata)
rawtraindata = rawdata[:300]
rawtestdata = rawdata[300:]
# Out:
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
train = rawtraindata[:,:-2]
lonTrain = rawtraindata[:,-2]
latTrain = rawtraindata[:,-1]

# %%
test = rawtestdata[:,:-2]
lonTest = np.array(rawtestdata[:,-2])
latTest = np.array(rawtestdata[:,-1])
print(lonTrain.shape,latTrain.shape)
# Out:
# (300,) (300,)

# %%
wslat = standRegres(train, latTrain)
wslon = standRegres(train, lonTrain)

# %%
xMat = np.mat(train)
lonHatArr1 = xMat*wslon
np.corrcoef(lonHatArr1.T, lonTrain)
# Out:
# array([[1.        , 0.94991161],
#        [0.94991161, 1.        ]])

# %%
xMat = np.mat(train)
latHatArr1 = xMat*wslat
np.corrcoef(latHatArr1.T, latTrain)
# Out:
# array([[1.       , 0.9494304],
#        [0.9494304, 1.       ]])

# %%
xMat = np.mat(test)
latHatArr = xMat*wslat
np.corrcoef(latHatArr.T, latTest)
# Out:
# array([[1.        , 0.92074056],
#        [0.92074056, 1.        ]])

# %%
xMat = np.mat(test)
lonHatArr = xMat*wslon
np.corrcoef(lonHatArr.T, lonTest)
# Out:
# array([[1.        , 0.93628347],
#        [0.93628347, 1.        ]])

# %%
rawdata = pd.DataFrame(rawtraindata)
rawlon = rawdata.iloc[:,[0,2]].values
rawlat = rawdata.iloc[:,[8,9]].values
rawlonlab = rawdata.iloc[:,16].values
rawlatlab = rawdata.iloc[:,17].values
plt.figure(figsize=(16, 8))
plt.scatter(rawlon[:,0], rawlonlab, color = 'red')
lonHatArr1 = np.squeeze(np.array(lonHatArr1))
plt.scatter(rawlon[:,0], lonHatArr1, color = 'blue')
plt.savefig("1")

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(rawlat[:,0], rawlon[:,0], rawlonlab)
ax.scatter(rawlat[:,0], rawlon[:,0], lonHatArr1)
ax.set_xlabel('V1')
ax.set_ylabel('V9')
ax.set_zlabel('LON')
plt.savefig("2")

# %%
plt.figure(figsize=(16, 8))
plt.scatter(rawlat[:,0], rawlatlab, color = 'red')
latHatArr1 = np.squeeze(np.array(latHatArr1))
plt.scatter(rawlat[:,0], latHatArr1, color = 'blue')
plt.savefig("3")

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(rawlat[:,0], rawlon[:,0], rawlatlab)
ax.scatter(rawlat[:,0], rawlon[:,0], latHatArr1)
ax.set_xlabel('V1')
ax.set_ylabel('V9')
ax.set_zlabel('LON')
plt.savefig("4")

# %%
from sklearn import linear_model
from math import *
trainX = train
lonTrainY = lonTrain
latTrainY = latTrain
testX = test
lonTestY = lonTest
latTestY = latTest
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-47c3eecdf740> in <module>
#       1 from sklearn import linear_model
#       2 from math import *
# ----> 3 trainX = train
#       4 lonTrainY = lonTrain
#       5 latTrainY = latTrain
#
# NameError: name 'train' is not defined

# %%
clf = linear_model.LinearRegression()
#clf = linear_model.Ridge(alpha = 0.8)
clf.fit(trainX,lonTrainY)
lonYHat = clf.predict(testX)
clf.fit(trainX,latTrainY)
latYHat = clf.predict(testX)

# %%
absErrorLon = absError(lonTestY,lonYHat)
absErrorLat = absError(latTestY,latYHat)

# %%
np.corrcoef(lonyHat, lonTestY[300:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f1d9f093e7bf> in <module>
# ----> 1 np.corrcoef(lonyHat, lonTestY[300:])
#
# NameError: name 'lonyHat' is not defined

# %%
rawdata = loadDataSet('./data/typhoon.dat').as_matrix()
random.shuffle(rawdata)
rawdata.shape
# Out:
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# (500, 18)

# %%
import matplotlib as mpl
import string
import pandas as pd 
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']
import seaborn as sns
sns.set_style({"font.sans-serif":['simhei', 'Arial']})


data_all = {'data size':[]}
data_Lon_Err = {'data size':[]}
data_Lat_Err = {'data size':[]}
data_Lon_corr = {'data size':[]}
data_Lat_corr = {'data size':[]}

for i in range(1,11):
    s = u'岭回归'+str(i/10)
    data_all[s]=[]
    data_Lon_Err[s+'Lon']=[]
    data_Lat_Err[s+'Lat']=[]
    data_Lon_corr[s+'Lon']=[]
    data_Lat_corr[s+'Lat']=[]

for train_num in range(250, 300, 1):
    rawtraindata = rawdata[:train_num]
    rawtestdata = rawdata[300:]
    trainX = rawtraindata[:,:-2]
    lonTrainY = rawtraindata[:,-2]
    latTrainY = rawtraindata[:,-1]
    testX = rawtestdata[:,:-2]
    lonTestY = np.array(rawtestdata[:,-2])
    latTestY = np.array(rawtestdata[:,-1])
    
    data_all['data size'].append(train_num)
    data_Lon_Err['data size'].append(train_num)
    data_Lat_Err['data size'].append(train_num)
    data_Lon_corr['data size'].append(train_num)
    data_Lat_corr['data size'].append(train_num)
    
    for i in range(1,11):
        key = i/10;
        clf = linear_model.Ridge (alpha = key) # 岭回归
        s = s = u'岭回归'+str(i/10)
        # 构建模型
        clf.fit (trainX, lonTrainY) # 训练经度模型
        lonyHat = clf.predict(testX) # 使用经度模型去预测经度
        clf.fit (trainX, latTrainY) # 训练纬度模型
        latyHat = clf.predict(testX) # 使用纬度模型去预测纬度
        # 经度误差
        absErrorLon = absError(lonTestY,lonyHat)
        # 纬度误差
        absErrorLat = absError(latTestY,latyHat)
        absErrorLen = 110 * sqrt(absErrorLon**2 + absErrorLat**2)

        data_all[s].append(absErrorLen)
        data_Lon_Err[s+'Lon'].append(absErrorLon)
        data_Lat_Err[s+'Lat'].append(absErrorLat)
        data_Lon_corr[s+'Lon'].append(np.corrcoef(lonyHat, lonTestY)[0][1])           
        data_Lat_corr[s+'Lat'].append(np.corrcoef(latyHat, latTestY)[0][1])
s = "岭回归"
titles = [u'训练样本量对预测距离误差的影响',
           u'训练样本量对预测经度误差的影响',
          u'训练样本量对预测纬度误差的影响',
          u'训练样本量对预测经度与真实经度之间相关系数的影响',
          u'训练样本量对预测纬度与真实纬度之间相关系数的影响']

data_all = pd.DataFrame(data_all)
data_all.set_index(['data size'], inplace=True)
data_all.plot( figsize=(12,8), title=titles[0])

plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[0])

data_Lon_Err = pd.DataFrame(data_Lon_Err)
data_Lon_Err.set_index(['data size'], inplace=True)
data_Lon_Err.plot(kind='line', figsize=(12,8),
             title=titles[1])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[1])

data_Lat_Err = pd.DataFrame(data_Lat_Err)
data_Lat_Err.set_index(['data size'], inplace=True)
data_Lat_Err.plot(kind='line', figsize=(12,8),
             title=titles[2])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[2])

data_Lon_corr = pd.DataFrame(data_Lon_corr)
data_Lon_corr.set_index(['data size'], inplace=True)
data_Lon_corr.plot(kind='line', figsize=(12,8),
             title=titles[3])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[3])

data_Lat_corr = pd.DataFrame(data_Lat_corr)
data_Lat_corr.set_index(['data size'], inplace=True)
data_Lat_corr.plot(kind='line', figsize=(12,8),
             title=titles[4])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[4])

# %%
import matplotlib as mpl
import string
import pandas as pd 
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']
import seaborn as sns
sns.set_style({"font.sans-serif":['simhei', 'Arial']})


data_all = {'data size':[]}
data_Lon_Err = {'data size':[]}
data_Lat_Err = {'data size':[]}
data_Lon_corr = {'data size':[]}
data_Lat_corr = {'data size':[]}

for i in range(1,10):
    s = u'Lasso回归'+str(i/20)
    data_all[s]=[]
    data_Lon_Err[s+'Lon']=[]
    data_Lat_Err[s+'Lat']=[]
    data_Lon_corr[s+'Lon']=[]
    data_Lat_corr[s+'Lat']=[]

for train_num in range(250, 300, 1):
    rawtraindata = rawdata[:train_num]
    rawtestdata = rawdata[300:]
    trainX = rawtraindata[:,:-2]
    lonTrainY = rawtraindata[:,-2]
    latTrainY = rawtraindata[:,-1]
    testX = rawtestdata[:,:-2]
    lonTestY = np.array(rawtestdata[:,-2])
    latTestY = np.array(rawtestdata[:,-1])
    
    data_all['data size'].append(train_num)
    data_Lon_Err['data size'].append(train_num)
    data_Lat_Err['data size'].append(train_num)
    data_Lon_corr['data size'].append(train_num)
    data_Lat_corr['data size'].append(train_num)
    
    for i in range(1,10):
        key = i/20;
        clf = linear_model.Lasso(alpha = key) 
        
        s = s = u'Lasso回归'+str(i/20)
        # 构建模型
        
        clf.fit (trainX, lonTrainY) # 训练经度模型
        lonyHat = clf.predict(testX) # 使用经度模型去预测经度
        clf.fit (trainX, latTrainY) # 训练纬度模型
        latyHat = clf.predict(testX) # 使用纬度模型去预测纬度
        # 经度误差
        absErrorLon = absError(lonTestY,lonyHat)
        # 纬度误差
        absErrorLat = absError(latTestY,latyHat)
        absErrorLen = 110 * sqrt(absErrorLon**2 + absErrorLat**2)

        data_all[s].append(absErrorLen)
        data_Lon_Err[s+'Lon'].append(absErrorLon)
        data_Lat_Err[s+'Lat'].append(absErrorLat)
        data_Lon_corr[s+'Lon'].append(np.corrcoef(lonyHat, lonTestY)[0][1])           
        data_Lat_corr[s+'Lat'].append(np.corrcoef(latyHat, latTestY)[0][1])
s = "Lasso回归"
titles = [u'训练样本量对预测距离误差的影响',
           u'训练样本量对预测经度误差的影响',
          u'训练样本量对预测纬度误差的影响',
          u'训练样本量对预测经度与真实经度之间相关系数的影响',
          u'训练样本量对预测纬度与真实纬度之间相关系数的影响']

data_all = pd.DataFrame(data_all)
data_all.set_index(['data size'], inplace=True)
data_all.plot( figsize=(12,8), title=titles[0])

plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[0])

data_Lon_Err = pd.DataFrame(data_Lon_Err)
data_Lon_Err.set_index(['data size'], inplace=True)
data_Lon_Err.plot(kind='line', figsize=(12,8),
             title=titles[1])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[1])

data_Lat_Err = pd.DataFrame(data_Lat_Err)
data_Lat_Err.set_index(['data size'], inplace=True)
data_Lat_Err.plot(kind='line', figsize=(12,8),
             title=titles[2])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[2])

data_Lon_corr = pd.DataFrame(data_Lon_corr)
data_Lon_corr.set_index(['data size'], inplace=True)
data_Lon_corr.plot(kind='line', figsize=(12,8),
             title=titles[3])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[3])

data_Lat_corr = pd.DataFrame(data_Lat_corr)
data_Lat_corr.set_index(['data size'], inplace=True)
data_Lat_corr.plot(kind='line', figsize=(12,8),
             title=titles[4])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[4])
# Out:
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.281118850955124, tolerance: 0.43260553599999996
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8721279930114179, tolerance: 0.43260553599999996
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3210639716932064, tolerance: 0.43260553599999996
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8792232073815285, tolerance: 0.43260553599999996
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.3704398781502505, tolerance: 0.44082022310756985
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9204114134454926, tolerance: 0.44082022310756985
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3547643931998437, tolerance: 0.44082022310756985
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9023009525207044, tolerance: 0.44082022310756985
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.259966167545372, tolerance: 0.44411860317460317
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8678138039811074, tolerance: 0.44411860317460317
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3065198167564063, tolerance: 0.44411860317460317
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8499595129786144, tolerance: 0.44411860317460317
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.217204727775197, tolerance: 0.4443333280632413
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8438586710230993, tolerance: 0.4443333280632413
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2755320702325434, tolerance: 0.4443333280632413
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8038303065928858, tolerance: 0.4443333280632413
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.242260426981375, tolerance: 0.46081245669291343
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8827161867836821, tolerance: 0.46081245669291343
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3108644392423798, tolerance: 0.46081245669291343
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8331174438852713, tolerance: 0.46081245669291343
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.257998551147921, tolerance: 0.462909349019608
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8855875110274951, tolerance: 0.462909349019608
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3021586347599623, tolerance: 0.462909349019608
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8103866521847749, tolerance: 0.462909349019608
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.428599007827302, tolerance: 0.46513771484375005
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9462266417710339, tolerance: 0.46513771484375005
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.327719841981434, tolerance: 0.46513771484375005
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.499018886379872, tolerance: 0.5253224383561644
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9936516276910652, tolerance: 0.5253224383561644
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.307678739721723, tolerance: 0.5253224383561644
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.461804017395366, tolerance: 0.5334538771331059
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9934230754735154, tolerance: 0.5334538771331059
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3109287029398047, tolerance: 0.5334538771331059
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.504002915511137, tolerance: 0.5334629693877552
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.018904631331111, tolerance: 0.5334629693877552
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3363823830765114, tolerance: 0.5334629693877552
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.480789812807075, tolerance: 0.5360541152542374
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0171653603317736, tolerance: 0.5360541152542374
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.334791059950362, tolerance: 0.5360541152542374
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.6305452617748415, tolerance: 0.5365013209459462
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0479202717474436, tolerance: 0.5365013209459462
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.362210149834823, tolerance: 0.5365013209459462
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.600576670068449, tolerance: 0.5365013333333335
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0407098493999456, tolerance: 0.5365013333333335
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3557171013274, tolerance: 0.5365013333333335
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.5956701875077215, tolerance: 0.5449165671140942
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.035801689689947, tolerance: 0.5449165671140942
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.349877297565513, tolerance: 0.5449165671140942
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.618897247535415, tolerance: 0.5458388160535118
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.047996031556522, tolerance: 0.5458388160535118
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.354331616824993, tolerance: 0.5458388160535118
#   positive)

# %%
import matplotlib as mpl
import string
import pandas as pd 
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']
import seaborn as sns
sns.set_style({"font.sans-serif":['simhei', 'Arial']})


data_all = {'data size':[]}
data_Lon_Err = {'data size':[]}
data_Lat_Err = {'data size':[]}
data_Lon_corr = {'data size':[]}
data_Lat_corr = {'data size':[]}


for i in range(1,20):
    s = u'ElasticNet回归'+str(i/20)
    data_all[s]=[]
    data_Lon_Err[s+'Lon']=[]
    data_Lat_Err[s+'Lat']=[]
    data_Lon_corr[s+'Lon']=[]
    data_Lat_corr[s+'Lat']=[]

for train_num in range(250, 300, 1):
    rawtraindata = rawdata[:train_num]
    rawtestdata = rawdata[300:]
    trainX = rawtraindata[:,:-2]
    lonTrainY = rawtraindata[:,-2]
    latTrainY = rawtraindata[:,-1]
    testX = rawtestdata[:,:-2]
    lonTestY = np.array(rawtestdata[:,-2])
    latTestY = np.array(rawtestdata[:,-1])
    
    data_all['data size'].append(train_num)
    data_Lon_Err['data size'].append(train_num)
    data_Lat_Err['data size'].append(train_num)
    data_Lon_corr['data size'].append(train_num)
    data_Lat_corr['data size'].append(train_num)
    
    for i in range(1,20):
        key = i/20;
        s = s = u'ElasticNet回归'+str(i/20)
        # 构建模型
        clf = linear_model.ElasticNet(alpha = key,max_iter=1000) # 岭回归
        clf.fit (trainX, lonTrainY) # 训练经度模型
        lonyHat = clf.predict(testX) # 使用经度模型去预测经度
        clf.fit (trainX, latTrainY) # 训练纬度模型
        latyHat = clf.predict(testX) # 使用纬度模型去预测纬度
        # 经度误差
        absErrorLon = absError(lonTestY,lonyHat)
        # 纬度误差
        absErrorLat = absError(latTestY,latyHat)
        absErrorLen = 110 * sqrt(absErrorLon**2 + absErrorLat**2)

        data_all[s].append(absErrorLen)
        data_Lon_Err[s+'Lon'].append(absErrorLon)
        data_Lat_Err[s+'Lat'].append(absErrorLat)
        data_Lon_corr[s+'Lon'].append(np.corrcoef(lonyHat, lonTestY)[0][1])           
        data_Lat_corr[s+'Lat'].append(np.corrcoef(latyHat, latTestY)[0][1])
        
s = "ElasticNet回归"
titles = [u'训练样本量对预测距离误差的影响',
           u'训练样本量对预测经度误差的影响',
          u'训练样本量对预测纬度误差的影响',
          u'训练样本量对预测经度与真实经度之间相关系数的影响',
          u'训练样本量对预测纬度与真实纬度之间相关系数的影响']


data_all = pd.DataFrame(data_all)
data_all.set_index(['data size'], inplace=True)
data_all.plot( figsize=(12,8), title=titles[0])

plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[0])

data_Lon_Err = pd.DataFrame(data_Lon_Err)
data_Lon_Err.set_index(['data size'], inplace=True)
data_Lon_Err.plot(kind='line', figsize=(12,8),
             title=titles[1])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[1])

data_Lat_Err = pd.DataFrame(data_Lat_Err)
data_Lat_Err.set_index(['data size'], inplace=True)
data_Lat_Err.plot(kind='line', figsize=(12,8),
             title=titles[2])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[2])

data_Lon_corr = pd.DataFrame(data_Lon_corr)
data_Lon_corr.set_index(['data size'], inplace=True)
data_Lon_corr.plot(kind='line', figsize=(12,8),
             title=titles[3])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[3])

data_Lat_corr = pd.DataFrame(data_Lat_corr)
data_Lat_corr.set_index(['data size'], inplace=True)
data_Lat_corr.plot(kind='line', figsize=(12,8),
             title=titles[4])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[4])
# Out:
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2158170433412465, tolerance: 0.5313487240000001
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3018500777963027, tolerance: 0.5345111713147415
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2800837290783988, tolerance: 0.5384489365079369
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2520197132999442, tolerance: 0.5465839367588934
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.233524337157121, tolerance: 0.5514668503937008
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3794010663149834, tolerance: 0.5523196313725491
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4103687038734734, tolerance: 0.5525394375000002
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4421572960324625, tolerance: 0.5525426536964981
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3735806373156265, tolerance: 0.5585704651162792
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3610331199127472, tolerance: 0.5593231583011584
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.365734755430367, tolerance: 0.5607906884615386
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6542761034473301, tolerance: 0.5607912720306515
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.600166020982556, tolerance: 0.5609658358778628
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6402150917771223, tolerance: 0.5610172927756658
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6619521032164357, tolerance: 0.5612170303030303
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8021168365429503, tolerance: 0.5627240603773588
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.75016242211899, tolerance: 0.5687459586466166
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7270732144501721, tolerance: 0.5691230337078654
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8556765539539128, tolerance: 0.5691298619402987
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8357045707439852, tolerance: 0.5695045055762082
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8605547451064695, tolerance: 0.5695049666666667
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8820815627940988, tolerance: 0.5715514907749079
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8745060180113455, tolerance: 0.571556117647059
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.899963245502363, tolerance: 0.577909252747253
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7488103654376914, tolerance: 0.5984090693430658
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7797172176094591, tolerance: 0.6023741818181818
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7974083283524465, tolerance: 0.6035846195652176
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7730311193590182, tolerance: 0.6046223249097474
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.753173537549685, tolerance: 0.6046690071942447
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.746136757891236, tolerance: 0.6089857706093192
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7745367394719551, tolerance: 0.6152968000000002
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7659641287212366, tolerance: 0.6154332028469751
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7597122895426196, tolerance: 0.6158584574468087
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6922965523212383, tolerance: 0.615864268551237
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6226690799334733, tolerance: 0.6190347429577467
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4665647924167047, tolerance: 0.6191117754385967
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.473045969538191, tolerance: 0.62892563986014
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5221476899264417, tolerance: 0.6293199372822301
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5095499131156203, tolerance: 0.6350489965277779
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.492359862811952, tolerance: 0.6351041730103808
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4997350584879996, tolerance: 0.6447896172413795
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4841213651670842, tolerance: 0.6449517525773196
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4796589640827165, tolerance: 0.6456105616438358
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1281261077912745, tolerance: 0.6500013924914678
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6622054869922067, tolerance: 0.6500013924914678
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1024865185311228, tolerance: 0.6538137823129254
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6748277074388511, tolerance: 0.6538137823129254
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0325751761149604, tolerance: 0.6539729966101697
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7084964888977652, tolerance: 0.6539729966101697
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0307116893567922, tolerance: 0.6547880000000004
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7088776913723791, tolerance: 0.6547880000000004
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0845001996727888, tolerance: 0.6566738787878792
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7344725520058546, tolerance: 0.6566738787878792
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.085544779078532, tolerance: 0.6569500536912756
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.740465309485387, tolerance: 0.6569500536912756
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0784828011766763, tolerance: 0.6572584481605356
#   positive)
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7380359382696611, tolerance: 0.6572584481605356
#   positive)

# %%
import matplotlib as mpl
import string
import pandas as pd 
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']
import seaborn as sns
sns.set_style({"font.sans-serif":['simhei', 'Arial']})

func_name_list = [u'最小二乘法',u'岭回归0.3',u'ElasticNet回归0.05',u'Lasso回归0.01'
                ,u'岭回归0.1']
func_list = ["linear_model.LinearRegression()"," linear_model.Ridge (alpha = 0.3)",
            " linear_model.ElasticNet(alpha=0.05,max_iter=50000)","linear_model.Lasso(alpha=0.01,max_iter=100000)","linear_model.Ridge (alpha = 0.1)"]

data_all = {'data size':[]}
data_Lon_Err = {'data size':[]}
data_Lat_Err = {'data size':[]}
data_Lon_corr = {'data size':[]}
data_Lat_corr = {'data size':[]}

;
for s in func_name_list:
    data_all[s]=[]
    data_Lon_Err[s+'Lon']=[]
    data_Lat_Err[s+'Lat']=[]
    data_Lon_corr[s+'Lon']=[]
    data_Lat_corr[s+'Lat']=[]


for train_num in range(50, 333, 1):
    rawtraindata = rawdata[:train_num]
    rawtestdata = rawdata[300:]
    trainX = rawtraindata[:,:-2]
    lonTrainY = rawtraindata[:,-2]
    latTrainY = rawtraindata[:,-1]
    testX = rawtestdata[:,:-2]
    lonTestY = np.array(rawtestdata[:,-2])
    latTestY = np.array(rawtestdata[:,-1])
    
    data_all['data size'].append(train_num)
    data_Lon_Err['data size'].append(train_num)
    data_Lat_Err['data size'].append(train_num)
    data_Lon_corr['data size'].append(train_num)
    data_Lat_corr['data size'].append(train_num)
    
    
    for i in range(len(func_list)):
        s = func_name_list[i]
        # 构建模型
        func = func_list[i]

        exec("clf="+func)


        clf.fit (trainX, lonTrainY) # 训练经度模型
        lonyHat = clf.predict(testX) # 使用经度模型去预测经度
        clf.fit (trainX, latTrainY) # 训练纬度模型
        latyHat = clf.predict(testX) # 使用纬度模型去预测纬度
        # 经度误差
        absErrorLon = absError(lonTestY,lonyHat)
        # 纬度误差
        absErrorLat = absError(latTestY,latyHat)
        absErrorLen = 110 * sqrt(absErrorLon**2 + absErrorLat**2)

        data_all[s].append(absErrorLen)
        data_Lon_Err[s+'Lon'].append(absErrorLon)
        data_Lat_Err[s+'Lat'].append(absErrorLat)
        data_Lon_corr[s+'Lon'].append(np.corrcoef(lonyHat, lonTestY)[0][1])           
        data_Lat_corr[s+'Lat'].append(np.corrcoef(latyHat, latTestY)[0][1])
        
s = "total"
titles = [u'训练样本量对预测距离误差的影响',
           u'训练样本量对预测经度误差的影响',
          u'训练样本量对预测纬度误差的影响',
          u'训练样本量对预测经度与真实经度之间相关系数的影响',
          u'训练样本量对预测纬度与真实纬度之间相关系数的影响']


data_all = pd.DataFrame(data_all)
data_all.set_index(['data size'], inplace=True)
data_all.plot( figsize=(12,8), title=titles[0])

plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[0])

data_Lon_Err = pd.DataFrame(data_Lon_Err)
data_Lon_Err.set_index(['data size'], inplace=True)
data_Lon_Err.plot(kind='line', figsize=(12,8),
             title=titles[1])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[1])

data_Lat_Err = pd.DataFrame(data_Lat_Err)
data_Lat_Err.set_index(['data size'], inplace=True)
data_Lat_Err.plot(kind='line', figsize=(12,8),
             title=titles[2])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[2])

data_Lon_corr = pd.DataFrame(data_Lon_corr)
data_Lon_corr.set_index(['data size'], inplace=True)
data_Lon_corr.plot(kind='line', figsize=(12,8),
             title=titles[3])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[3])

data_Lat_corr = pd.DataFrame(data_Lat_corr)
data_Lat_corr.set_index(['data size'], inplace=True)
data_Lat_corr.plot(kind='line', figsize=(12,8),
             title=titles[4])
plt.legend(bbox_to_anchor=(1.0, 1))
plt.savefig(s+titles[4])

# %%
#lat
rawdata = loadDataSet('./data/typhoon.dat').as_matrix()
testX = loadDataSet('./data/typhoon200Test_7.dat').as_matrix()
random.shuffle(rawdata)
rawtraindata = rawdata
trainX = rawtraindata[:,:-2]
lonTrainY = rawtraindata[:,-2]
latTrainY = rawtraindata[:,-1]
# Out:
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# C:\Users\17668\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
testX.shape
# Out:
# (200, 16)

# %%
clf = linear_model.LinearRegression()
clf.fit (trainX, latTrainY) # 训练经度模型
latyHat = clf.predict(testX) # 使用经度模型去预测经度
# clf.fit (trainX, latTrainY) # 训练纬度模型
# latyHat = clf.predict(testX) # 使用纬度模型去预测纬度
# linear_model.Lasso(alpha=0.01,max_iter=100000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-577aa0364dca> in <module>
#       1 cif = linear_model.LinearRegression()
# ----> 2 clf.fit (trainX, latTrainY) # 训练经度模型
#       3 latyHat = clf.predict(testX) # 使用经度模型去预测经度
#       4 # clf.fit (trainX, latTrainY) # 训练纬度模型
#       5 # latyHat = clf.predict(testX) # 使用纬度模型去预测纬度
#
# NameError: name 'clf' is not defined

# %%
cif = linear_model.Lasso(alpha=0.01,max_iter=100000)
clf.fit (trainX, lonTrainY) # 训练经度模型
lonyHat = clf.predict(testX)

# %%
#f  = open("10175102247-typhoon200Result.dat","a+")
lonyHat
# Out:
# array([114.50657115, 111.81287696, 111.53445488, 112.82024342,
#        121.60044323, 113.88971201, 109.18804522, 114.69437835,
#        107.34815251, 114.40459958, 122.10529034, 111.82527614,
#        106.93918681, 109.30514579, 119.60629839, 116.08191752,
